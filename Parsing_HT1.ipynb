# %%
import requests
import json
import pprint

# %%
url = 'https://api.github.com'
user='d4rkfl4me'

# %%
r = requests.get(f'{url}/users/{user}/repos')
with open('data.json', 'w') as f:
    json.dump(r.json(), f)
for i in r.json():
    print(i['name'])
# Out:
# d4rkfl4me
# GeekBrains_AI
# Linear_algebra_GB
# probability_theory
# probability_theory-1
# project
# Python_Data_Science

# %%
url = 'https://api.vk.com/method/'
token = 'vk1.a.PP0w_PuYr2H3XGEiGZxyMNjifw66Q9D7cTy0BGrMP6tSIjsCawIbjiJFDwzrZ95H15U6j9SlYAFh1-nfuiaAKAzBlH2Hb2m213XOZNK0Nku6WWmRzHIE0IJ8ZYZyqhtE8CEME9QpzX5InQflBbVtFmq34WSDvbqv1IzVK-jr9-N_pZ-wPX6j7SV9WUu5i-cW7Q_BVbZF6HGI2syXQzoz_A'
user_id = '727890'

# %%
headers = {
    'Content-Type': 'application/json', \
    'Authorization': token
}

# %%
response = requests.get(f'{url}/groups.get?{user_id}&extended=1&access_token={token}&v=5.131')
response.json()
# Out:
# {'response': {'count': 196,
#   'items': [{'id': 59707832,
#     'name': 'Я за Путина / ZOV',
#     'screen_name': 'kps63',
#     'is_closed': 0,
#     'type': 'group',
#     'is_admin': 0,
#     'is_member': 1,
#     'is_advertiser': 0,
#     'photo_50': 'https://sun1.beeline-kz.userapi.com/s/v1/ig2/LZwHDNtFF9TIdF1Nh_hUHChcefoRPBVgDPD7sDpP32N4RqWkIW070M4E8H9cPDgrtPqhFqmOrFAX6ZMcckngl6YD.jpg?size=50x50&quality=96&crop=31,6,428,428&ava=1',
#     'photo_100': 'https://sun1.beeline-kz.userapi.com/s/v1/ig2/VVN6wy_i_fPlOD5vsNcsHZ2PGX1NBPS3laDAzGBaeNFh4qFqN6Oy-pV_rArQ6rqGp70GJGXuv0XilZpi9b66O0qK.jpg?size=100x100&quality=96&crop=31,6,428,428&ava=1',
#     'photo_200': 'https://sun1.beeline-kz.userapi.com/s/v1/ig2/mpXvRfqatiIMRY2Cd4-tlzjgkl6HOSZXMZPQ6cHdFZOKFrloTHgrWRe-g-unPz9eaHOgGCxkEGBo66OHnvVkrU4N.jpg?size=200x200&quality=96&crop=31,6,428,428&ava=1'},
#    {'id': 197035212,
#     'name': 'GreenGrass',
#     'screen_name': 'greenwasgrass',
#     'is_closed': 0,
#     'type': 'page',
# ...
