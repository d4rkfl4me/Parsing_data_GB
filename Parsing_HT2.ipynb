# %%
from pprint import pprint
from lxml import html
import requests
import pandas as pd

# %%
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
URL_YANDEX_NEWS = 'https://yandex.ru/news/'
URL_LENTA_NEWS = 'https://lenta.ru/'
URL_DZEN_NEWS = 'https://dzen.ru/news/'

# %%
headers = {
    'User-Agent': USER_AGENT,
}

params = {
    'sso_failed': '',
}

# %%
def get_content_dom_from_html_text(url, headers=None, params=None):
    response = requests.get(url, headers=headers, params=params)
    content_dom = html.fromstring(response.text)

    print(response.url)
    
    return content_dom


def parser_yandex_news(content_dom):
    news_container = content_dom.xpath("//section//div[contains(@class, 'mg-grid__item')]")
    yandex_news = []
    for new_container in news_container:
        new_source = new_container.xpath(".//div[@class='mg-card-footer__left']//a/text()")[0]
        new_text = new_container.xpath(".//h2/a/text()")[0].replace('\xa0', ' ')
        new_link = new_container.xpath(".//h2/a/@href")[0]
        new_date = new_container.xpath(".//span[@class='mg-card-source__time']/text()")[0]
        news_dict = {
            'new_source': new_source,
            'new_text': new_text,
            'new_link': new_link,
            'new_date': new_date,
        }
        yandex_news.append(news_dict)

    return yandex_news


def parser_dzen_news(content_dom):
    news_container = content_dom.xpath("//div[contains(@class,'mg-card ')]")
    dzen_news = []
    for new_container in news_container:
        new_source = new_container.xpath(".//a[@class='mg-card__source-link']/text()")[0]
        new_text = new_container.xpath(".//h2/a/text()")[0].replace('\xa0', ' ')
        new_link = new_container.xpath(".//h2/a/@href")[0]
        new_date = new_container.xpath(".//span[@class='mg-card-source__time']/text()")[0]
        news_dict = {
            'new_source': new_source,
            'new_text': new_text,
            'new_link': new_link,
            'new_date': new_date,
        }
        dzen_news.append(news_dict) 

    return dzen_news


def parser_lenta_news(content_dom):
    news_container = content_dom.xpath("//a[contains(@class, 'card-')]")
    lenta_news = []
    for new_container in news_container:
        new_source = new_container.xpath(".//*[name()='svg']/*[name()='use']/attribute::*")
        if len(new_source) == 1:
            new_source = new_source[0].split('ui-label_')
            if len(new_source) == 2:
                new_source = new_source[1]
            else:
                new_source = 'Lenta.ru'
        else:
            new_source = 'Lenta.ru' 
        new_text = new_container.xpath(".//span[contains(@class, 'card-')]/text()")
        if len(new_text) == 1:
            new_text = new_text[0]
        else:
            new_text = None  
        new_link = URL_LENTA_NEWS + new_container.xpath("./@href")[0]
        
        new_date = new_container.xpath(".//time/text()")
        if len(new_date) == 1:
            new_date = new_date[0]
        else:
            new_date = None
        news_dict = {
            'new_source': new_source,
            'new_text': new_text,
            'new_link': new_link,
            'new_date': new_date,
        }
        lenta_news.append(news_dict)
        
    return lenta_news


def get_news(content_dom, parser_name='dzen'):
    result = None
    
    if parser_name == 'dzen':
      result = parser_dzen_news(content_dom)
    elif parser_name == 'yandex':
      result = parser_yandex_news(content_dom)
    elif parser_name == 'lenta':
      result = parser_lenta_news(content_dom)
    
    return result

# %%
dom = get_content_dom_from_html_text(URL_DZEN_NEWS, headers=headers, params=params)
# Out:
# https://dzen.ru/news?issue_tld=kz&sso_failed=

# %%
dzen_news = get_news(dom, 'dzen')
dzen_news
# Out:
# [{'new_source': 'Московский Комсомолец',
#   'new_text': 'Представитель Казахстана вступил в должность генерального секретаря ОДКБ',
#   'new_link': 'https://dzen.ru/news/story/Predstavitel_Kazakhstana_vstupil_vdolzhnost_generalnogo_sekretarya_ODKB--98650ed5741925105cb13d94e042aef4?lang=ru&rubric=index&fan=1&stid=mQMmzLfhS4bIgHdm01c4&t=1672592347&persistent_id=1234564460&story=08c7bf44-82bd-5ef2-937a-7ebd5637fa6f&issue_tld=kz',
#   'new_date': '19:06'},
#  {'new_source': '24.kz',
#   'new_text': 'Список социально-экономических преобразований составили в Правительстве',
#   'new_link': 'https://dzen.ru/news/story/Spisok_socialno-ehkonomicheskikh_preobrazovanij_sostavili_vPravitelstve--741a8093d190ddb86798fa96bd83e97a?lang=ru&rubric=index&fan=1&stid=dHTkk7DVoMxi5NP9&t=1672592347&persistent_id=1234564336&story=d4e79d83-e724-58e6-a958-57120782a29d&issue_tld=kz',
#   'new_date': '16:10'},
#  {'new_source': 'REGNUM',
#   'new_text': 'Президент Казахстана подписал закон о развитии агломераций',
#   'new_link': 'https://dzen.ru/news/story/Prezident_Kazakhstana_podpisal_zakon_orazvitii_aglomeracij--b1339f32789077f687ea4a6d6c5cf78b?lang=ru&rubric=index&fan=1&stid=_OTyhjNXWnBGUbioQB9X&t=1672592347&persistent_id=1236560695&story=b1f670d8-3681-551b-bbbf-39dc58d9ce9a&issue_tld=kz',
#   'new_date': '17:54'},
#  {'new_source': 'Zakon.kz',
#   'new_text': 'Два человека погибли при опрокидывании машины близ Талдыкоргана',
#   'new_link': 'https://dzen.ru/news/story/Dva_cheloveka_pogibli_prioprokidyvanii_mashiny_blizTaldykorgana--a7dbdd9ac8bbabb8b88d5e3e8caf7152?lang=ru&rubric=index&fan=1&stid=hXtGN0RM4uAz23NJ3j0Q&t=1672592347&persistent_id=1234960173&story=aa054c55-4572-57cc-b48f-0ec093924e0d&issue_tld=kz',
#   'new_date': '22:38'},
#  {'new_source': 'Zakon.kz',
#   'new_text': 'В канун Нового года в Казахстане родились 240 малышей',
#   'new_link': 'https://dzen.ru/news/story/Vkanun_Novogo_goda_vKazakhstane_rodilis_240_malyshej--a61a6656e52a0043243e404c2fe5b170?lang=ru&rubric=index&fan=1&stid=_0mb7l8solCWHK-KQg0l&t=1672592347&persistent_id=1236960890&story=a6861a89-b4ef-5133-afb5-c8d9644466b1&issue_tld=kz',
#   'new_date': '18:41'},
#  {'new_source': 'Чемпионат',
#   'new_text': 'Александр Овечкин забил 804-й гол в Национальной хоккейной лиге',
#   'new_link': 'https://dzen.ru/news/story/Aleksandr_Ovechkin_zabil_804-j_gol_vNacionalnoj_khokkejnoj_lige--fb50991c07b6f78b886a4994f6d21e1e?lang=ru&rubric=personal_feed&fan=1&stid=TRrqEEwoLg1vYDc0xm07&t=1672592347&persistent_id=1208160282&story=5deac8ab-d047-590e-9fdf-1695d380c54d&issue_tld=kz',
#   'new_date': '20:41'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'МВД сообщило о задержании двух тысяч мигрантов в центре Петербурга в новогоднюю ночь',
#   'new_link': 'https://dzen.ru/news/story/MVD_soobshhilo_ozaderzhanii_dvukh_tysyach_migrantov_vcentre_Peterburga_vnovogodnyuyu_noch--ead8865cc6c3fca44f2d8d8b14dcbe56?lang=ru&rubric=personal_feed&fan=1&stid=NQ165XjJ-J2kZ6gPT0Ac&t=1672592347&tt=true&persistent_id=1238162440&story=7ea2ba0c-0e9f-589e-9ed4-fedb3a86e0ae&issue_tld=kz',
#   'new_date': '22:56'},
#  {'new_source': 'Ferra',
#   'new_text': 'На ввозимые в РФ смартфоны теперь обязаны устанавливать приложения VK, Яндекса и Rutube',
#   'new_link': 'https://dzen.ru/news/story/Navvozimye_vRF_smartfony_teper_obyazany_ustanavlivat_prilozheniya_VK_YAndeksa_i_Rutube--cf7ebd308ecb11a3a6b30e4d962f5b80?lang=ru&rubric=personal_feed&fan=1&stid=KiU_xkgmqZL_h2bSF82Y&t=1672592347&persistent_id=1230161092&story=2487b8ca-5b9b-58e8-b51f-666f4d42a6fb&issue_tld=kz',
#   'new_date': '22:23'},
#  {'new_source': 'Телеканал 360°',
#   'new_text': 'Подполковник армии США Дэвис: лидер страны Байден не стал обещать Украине бронетехнику',
#   'new_link': 'https://dzen.ru/news/story/Podpolkovnik_armii_SSHA_Dehvis_lider_strany_Bajden_ne_stal_obeshhat_Ukraine_bronetekhniku--5beabed60b4d24eabc4f7ca34e09bcec?lang=ru&rubric=personal_feed&fan=1&stid=M3RfbvX5xKaItNjU9C4Q&t=1672592347&persistent_id=1238960298&story=a8c4189f-67ee-5abd-98f6-79f0b0a4454a&issue_tld=kz',
#   'new_date': '22:57'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'OneTwoTrip назвал Москву, Сочи и Турцию популярными направлениями у россиян в январе',
#   'new_link': 'https://dzen.ru/news/story/OneTwoTrip_nazval_Moskvu_Sochi_i_Turciyu_populyarnymi_napravleniyami_urossiyan_vyanvare--b6ab426160fe000d7de345b1f2d549d7?lang=ru&rubric=personal_feed&fan=1&stid=Bj4I0IegBlpGDKziw1uy&t=1672592347&tt=true&persistent_id=1234563327&story=f2482990-a26a-5fc6-9130-f06610091910&issue_tld=kz',
#   'new_date': '22:56'},
#  {'new_source': 'ТАСС',
#   'new_text': 'Ким Чен Ын поручил создать новую межконтинентальную баллистическую ракету',
#   'new_link': 'https://dzen.ru/news/story/Kim_CHen_Yn_poruchil_sozdat_novuyu_mezhkontinentalnuyu_ballisticheskuyu_raketu--90463a5e08375c5a0a7046f25e9737ee?lang=ru&rubric=politics&fan=1&stid=3dEpXllu1UO96d1664nL&t=1672592347&persistent_id=1234561097&story=458a555f-ae11-5037-8cb4-e9e9db9b71e9&issue_tld=kz',
#   'new_date': '22:12'},
#  {'new_source': '24.kz',
#   'new_text': 'Иран провёл испытание военных беспилотников',
#   'new_link': 'https://dzen.ru/news/story/Iran_provyol_ispytanie_voennykh_bespilotnikov--25053c250e5ace816106ec14f5e3e717?lang=ru&rubric=politics&fan=1&t=1672592347&persistent_id=1232960936&story=ec8a9e28-80ce-5ee7-ba4e-d80561cbb33b&issue_tld=kz',
#   'new_date': '20:35'},
#  {'new_source': 'Forbes Казахстан',
#   'new_text': 'Владимир Зеленский выразил уверенность в победе Украины в 2023 году',
#   'new_link': 'https://dzen.ru/news/story/Vladimir_Zelenskij_vyrazil_uverennost_vpobede_Ukrainy_v2023_godu--d5ae9fcfd7085044a20c7c80104e8a7c?lang=ru&rubric=politics&fan=1&t=1672592347&persistent_id=1238162326&story=0701bfd1-f19c-543d-a80e-444d5a804cdd&issue_tld=kz',
#   'new_date': '19:49'},
#  {'new_source': 'REGNUM',
#   'new_text': 'Швеция с 1 января 2023 года принимает председательство в Совете Евросоюза',
#   'new_link': 'https://dzen.ru/news/story/SHveciya_s1_yanvarya_2023_goda_prinimaet_predsedatelstvo_vSovete_Evrosoyuza--72441634472fa8fccf73a8e59a2f85d7?lang=ru&rubric=politics&fan=1&stid=Gs-WSGEFSTes_Mr3&t=1672592347&persistent_id=1234560494&story=39d0cbc8-9677-51fa-9bfd-34283ac79c9f&issue_tld=kz',
#   'new_date': '21:56'},
#  {'new_source': 'Российская газета',
#   'new_text': 'Германия возглавила силы быстрого реагирования НАТО',
#   'new_link': 'https://dzen.ru/news/story/Germaniya_vozglavila_sily_bystrogo_reagirovaniya_NATO--2617f7d3a3da64e7f54d2613437b9051?lang=ru&rubric=politics&fan=1&stid=aryz&t=1672592347&persistent_id=1160160651&story=9fc1326d-a83a-597e-a24b-2c31a0abaa89&issue_tld=kz',
#   'new_date': '20:44'},
#  {'new_source': 'REGNUM',
#   'new_text': 'Размеры социальных пособий и минимальной зарплаты в Казахстане выросли более чем на 12%',
#   'new_link': 'https://dzen.ru/news/story/Razmery_socialnykh_posobij_i_minimalnoj_zarplaty_vKazakhstane_vyrosli_bolee_chem_na12--f5874b3b5d0376105bfb8f7b4ce0a0e4?lang=ru&rubric=society&fan=1&stid=ouHE2Fblw529_rcC4XQC&t=1672592347&persistent_id=1234563583&story=7db90ddf-3158-5a0d-a42c-8435c9cc162f&issue_tld=kz',
#   'new_date': '17:21'},
#  {'new_source': 'Ридус',
#   'new_text': 'Казахи снова вышли на акции протеста в Жанаозене',
#   'new_link': 'https://dzen.ru/news/story/Kazakhi_snova_vyshli_naakcii_protesta_vZHanaozene--9671a58a60462865fdb854d570b79926?lang=ru&rubric=society&fan=1&stid=bzUV&t=1672592347&persistent_id=1238160150&story=de23cee7-b376-50e4-960c-d45f4f524f80&issue_tld=kz',
#   'new_date': '22:50'},
#  {'new_source': 'РИА Новости',
#   'new_text': 'Босфорский пролив закрыли для движения судов из-за сильного тумана',
#   'new_link': 'https://dzen.ru/news/story/Bosforskij_proliv_zakryli_dlyadvizheniya_sudov_iz-zasilnogo_tumana--edcc5e6000efe8776664bc2e4c7ac879?lang=ru&rubric=society&fan=1&stid=UeZogJxIrC7M2UVhf7NG&t=1672592347&persistent_id=1234565299&story=9cb6e758-c239-5658-93e3-a242ae301c1d&issue_tld=kz',
#   'new_date': '22:38'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'Хорватия с 1 января 2023 года вошла в Шенгенское соглашение по визам и еврозону',
#   'new_link': 'https://dzen.ru/news/story/KHorvatiya_s1_yanvarya_2023_goda_voshla_vSHengenskoe_soglashenie_povizam_i_evrozonu--77d15d2d2ec4afc9fe57fde993cdf3d3?lang=ru&rubric=society&fan=1&stid=XpczIf8z8oR6qdwJOMaF&t=1672592347&persistent_id=1215360177&story=32877f9e-6819-51ee-8531-4d4ce8b39b0a&issue_tld=kz',
#   'new_date': '22:34'},
#  {'new_source': 'Деловой Казахстан',
#   'new_text': 'Новогодний фейерверк запустили в Астане',
#   'new_link': 'https://dzen.ru/news/story/Novogodnij_fejerverk_zapustili_vAstane--a007a2526eb8c64120b6a2c90554329c?lang=ru&rubric=society&fan=1&stid=30uQ&t=1672592347&persistent_id=1237360574&story=00e57f37-e126-526a-861f-407357715eb5&issue_tld=kz',
#   'new_date': '20:15'},
#  {'new_source': 'Алау ТВ',
#   'new_text': 'Переехавшие за границу казахстанцы забрали из ЕНПФ более 45 млрд тенге',
#   'new_link': 'https://dzen.ru/news/story/Pereekhavshie_zagranicu_kazakhstancy_zabrali_izENPF_bolee_45_mlrd_tenge--55e9feb7aaa9fc86dd2d7e96153d2f32?lang=ru&rubric=business&fan=1&t=1672592347&persistent_id=1174560591&story=0e88914c-386c-5882-a6c7-6e1f200d3113&issue_tld=kz',
#   'new_date': '12:30'},
#  {'new_source': '24.kz',
#   'new_text': 'НДС для рыболовных предприятий снизили на 70%',
#   'new_link': 'https://dzen.ru/news/story/NDS_dlyarybolovnykh_predpriyatij_snizili_na70--ad3b16af3a016a0b54e9792bd5582ba6?lang=ru&rubric=business&fan=1&t=1672592347&persistent_id=1234563659&story=13ef5d06-3d97-5bf3-970c-e6c1c12dc51d&issue_tld=kz',
#   'new_date': '09:34'},
#  {'new_source': 'RT на русском',
#   'new_text': 'В Болгарии в первый день января природный газ подорожал с €73 до €92',
#   'new_link': 'https://dzen.ru/news/story/VBolgarii_vpervyj_den_yanvarya_prirodnyj_gaz_podorozhal_s73_do92--93c0af5f3c32b8d543bda90ff0881e62?lang=ru&rubric=business&fan=1&stid=RPz8WdQu7jQdcb_61lbj&t=1672592347&tt=true&persistent_id=1238162227&story=bf0b152c-4714-5624-ae7c-985164db053c&issue_tld=kz',
#   'new_date': '22:22'},
#  {'new_source': 'Газета.Ru',
#   'new_text': 'Министр финансов Германии Линднер считает, что цены на газ останутся высокими',
#   'new_link': 'https://dzen.ru/news/story/Ministr_finansov_Germanii_Lindner_schitaet_chto_ceny_nagaz_ostanutsya_vysokimi--2a82972f3a83fa8848360517fe43b903?lang=ru&rubric=business&fan=1&stid=7J7GCSH2mO7S5HvZ5F0K&t=1672592347&tt=true&persistent_id=1238162779&story=bfc9373a-c42e-541b-855a-92b0df173471&issue_tld=kz',
#   'new_date': '22:53'},
#  {'new_source': 'ПРАЙМ',
#   'new_text': 'Власти Молдавии повысили налог на доход с банковских депозитов с трех до семи процентов',
#   'new_link': 'https://dzen.ru/news/story/Vlasti_Moldavii_povysili_nalog_nadokhod_sbankovskikh_depozitov_strekh_dosemi_procentov--bbf092c604c63a1860f3db0e04670fd6?lang=ru&rubric=business&fan=1&stid=jdjt&t=1672592347&persistent_id=1234565286&story=1fef1b77-4fd2-55d1-aa5a-f7132dd290e4&issue_tld=kz',
#   'new_date': '22:29'},
#  {'new_source': 'Газета.Ru',
#   'new_text': 'В Нью-Йорке трое полицейских пострадали при нападении 19-летнего мужчины с мачете',
#   'new_link': 'https://dzen.ru/news/story/VNyu-Jorke_troe_policejskikh_postradali_prinapadenii_19-letnego_muzhchiny_smachete--84df8b577411902ba01bb7da3d6e144a?lang=ru&rubric=world&fan=1&stid=x7Nn-Z6btkuroNcCE2OJ&t=1672592347&tt=true&persistent_id=1234566415&story=1d733e38-5b5e-51d2-a147-6a52cea9fa34&issue_tld=kz',
#   'new_date': '21:45'},
#  {'new_source': 'Известия',
#   'new_text': 'В Турции начал действовать налог на проживание туристов в размере 2%',
#   'new_link': 'https://dzen.ru/news/story/VTurcii_nachal_dejstvovat_nalog_naprozhivanie_turistov_vrazmere_2--e19984c757ccfbf0f7d6f8a8715f0e28?lang=ru&rubric=world&fan=1&stid=MPYvG-cGpaigPUaQF4UD&t=1672592347&persistent_id=1008563070&story=644c0611-7dbd-5746-8732-c2086c6c07f9&issue_tld=kz',
#   'new_date': '22:54'},
#  {'new_source': 'Lenta.ru',
#   'new_text': 'В Белграде ночной клуб Freestyler затонул во время новогодней вечеринки',
#   'new_link': 'https://dzen.ru/news/story/VBelgrade_nochnoj_klub_Freestyler_zatonul_vo_vremya_novogodnej_vecherinki--381054247397b36122ada4f3a51d29aa?lang=ru&rubric=world&fan=1&stid=uoH1-6XjvzG2lqm9zsE1&t=1672592347&tt=true&persistent_id=1234562865&story=69363476-1753-5926-977a-d8ba862e21d6&issue_tld=kz',
#   'new_date': '21:57'},
#  {'new_source': 'Zakon.kz',
#   'new_text': 'В Китае учебным заведениям разрешили перейти в офлайн формат',
#   'new_link': 'https://dzen.ru/news/story/VKitae_uchebnym_zavedeniyam_razreshili_perejti_voflajn_format--6a875954d9eed605a28bad4fdb8c317f?lang=ru&rubric=world&fan=1&stid=BCJo&t=1672592347&persistent_id=1230161806&story=f3995a36-0c52-5527-9dad-d2874453335d&issue_tld=kz',
#   'new_date': '15:46'},
#  {'new_source': 'Газета.Ru',
#   'new_text': 'В британском Скарборо отложили запуск фейерверков из-за моржа Тора',
#   'new_link': 'https://dzen.ru/news/story/Vbritanskom_Skarboro_otlozhili_zapusk_fejerverkov_iz-zamorzha_Tora--6b14d9197bbd5efe4074e28d2245e9df?lang=ru&rubric=world&fan=1&stid=myV6ic8QYOn2fVbbX8as&t=1672592347&persistent_id=1234564340&story=3eb1b759-2199-57ac-a028-17b990addd92&issue_tld=kz',
#   'new_date': '21:30'},
#  {'new_source': 'ИА Красная Весна',
#   'new_text': 'Теннисист Бублик проиграл Гуркачу на Объединенном кубке в Австралии',
#   'new_link': 'https://dzen.ru/news/story/Tennisist_Bublik_proigral_Gurkachu_naObedinennom_kubke_vAvstralii--46a2de19a5dc08fdb47a0813f1aca50b?lang=ru&rubric=sport&fan=1&t=1672592347&persistent_id=1213360646&story=bd0de2d3-539b-50ba-82a9-a5a02e743067&issue_tld=kz',
#   'new_date': '19:57'},
#  {'new_source': 'Sports.kz',
#   'new_text': '«Барыс» в январе провел самый веселый матч в истории КХЛ',
#   'new_link': 'https://dzen.ru/news/story/Barys_vyanvare_provel_samyj_veselyj_match_vistorii_KKHL--e94bb02b37b6f0121e15039f39c0899a?lang=ru&rubric=sport&fan=1&stid=iVtmLCGA3uF7&t=1672592347&persistent_id=1238162251&story=8f6fdac8-ae13-58f6-a725-827bc499d923&issue_tld=kz',
#   'new_date': '20:59'},
#  {'new_source': 'Sports.kz',
#   'new_text': 'Бибисара Асаубаева назвала десять хороших событий 2022 года',
#   'new_link': 'https://dzen.ru/news/story/Bibisara_Asaubaeva_nazvala_desyat_khoroshikh_sobytij_2022_goda--3ec9ed3d20b3805e6d83243a4455b5c6?lang=ru&rubric=sport&fan=1&stid=fFuo&t=1672592347&persistent_id=1238160862&story=99bd1f76-8889-55bc-8f02-1ec6ac888b4f&issue_tld=kz',
#   'new_date': '18:46'},
#  {'new_source': 'PROСПОРТ Казахстан',
#   'new_text': 'Михаил Кукушкин с поражения начал сезон 2023 года',
#   'new_link': 'https://dzen.ru/news/story/Mikhail_Kukushkin_sporazheniya_nachal_sezon_2023_goda--b08bb48679259830cba001b61bed3deb?lang=ru&rubric=sport&fan=1&stid=OKbM&t=1672592347&persistent_id=1234564737&story=d294dc85-31b7-58d4-a3b4-55eb7bc1bd46&issue_tld=kz',
#   'new_date': '17:51'},
#  {'new_source': 'Bookmaker-ratings.ru',
#   'new_text': 'Переход полузащитника «Хетафе» Максимовича в «Спартак» может не состояться',
#   'new_link': 'https://dzen.ru/news/story/Perekhod_poluzashhitnika_KHetafe_Maksimovicha_vSpartak_mozhet_ne_sostoyatsya--19d2b2ef2a8205edc3071945004ebb2f?lang=ru&rubric=sport&fan=1&stid=JmG80YAGOr7mLAVUL1OT&t=1672592347&persistent_id=1234566712&story=20a34234-4189-5c22-bd51-25d7152267b8&issue_tld=kz',
#   'new_date': '19:25'},
#  {'new_source': 'Tengrinews.kz',
#   'new_text': 'В пригороде Кызылорды сгорела новогодняя елка',
#   'new_link': 'https://dzen.ru/news/story/Vprigorode_Kyzylordy_sgorela_novogodnyaya_elka--8a9a248b2cd20a73b29f88f46c66df4f?lang=ru&rubric=incident&fan=1&stid=NydWMhbvn4IT1BbHCcWw&t=1672592347&persistent_id=1235760006&story=f83ef574-5ffc-5124-8547-95c05ec71936&issue_tld=kz',
#   'new_date': '17:43'},
#  {'new_source': 'Литер',
#   'new_text': 'Заблудившихся в новогоднюю ночь в степи Костанайской области мужчин спасли полицейские',
#   'new_link': 'https://dzen.ru/news/story/Zabludivshikhsya_vnovogodnyuyu_noch_vstepi_Kostanajskoj_oblasti_muzhchin_spasli_policejskie--325dc9e2ee743b6d62b61965a80ccab8?lang=ru&rubric=incident&fan=1&stid=7i9u9lTI&t=1672592347&persistent_id=1237760227&story=324a47c0-4df1-5643-8981-795d69c23fa1&issue_tld=kz',
#   'new_date': '20:24'},
#  {'new_source': 'РЕН ТВ',
#   'new_text': 'Три человека погибли и 10 ранены в результате стрельбы в городе Мобил',
#   'new_link': 'https://dzen.ru/news/story/Tri_cheloveka_pogibli_i_10_raneny_vrezultate_strelby_vgorode_Mobil--83c422b359c9af3f3a94cb69d9b690ed?lang=ru&rubric=incident&fan=1&stid=23IxboiiXwCpB24YfuWU&t=1672592347&persistent_id=1235760058&story=5a511a39-45dc-5006-a96b-98a6fb73e2a5&issue_tld=kz',
#   'new_date': '22:54'},
#  {'new_source': 'Казинформ',
#   'new_text': 'Спасшего четырех человек пожарного наградили в Павлодаре',
#   'new_link': 'https://dzen.ru/news/story/Spasshego_chetyrekh_chelovek_pozharnogo_nagradili_vPavlodare--6d91bf611f285adddec633ee9d76f75b?lang=ru&rubric=incident&fan=1&stid=3-MIzq3lXrT9&t=1672592347&persistent_id=1234564853&story=97546455-aff8-57ef-8729-9073746fed67&issue_tld=kz',
#   'new_date': '18:11'},
#  {'new_source': 'Tengrinews.kz',
#   'new_text': 'Жительница Актобе погибла при пожаре в новогоднюю ночь',
#   'new_link': 'https://dzen.ru/news/story/ZHitelnica_Aktobe_pogibla_pripozhare_vnovogodnyuyu_noch--49242c917b9854461179578b80591cf0?lang=ru&rubric=incident&fan=1&stid=Mnpe4ss1iZ3Q&t=1672592347&persistent_id=1234565592&story=e1b5d42c-bd31-5f58-8ef4-e3dcd1d102f6&issue_tld=kz',
#   'new_date': '15:34'},
#  {'new_source': 'Казинформ',
#   'new_text': 'Театр «Астана Балет» представил афишу на январь',
#   'new_link': 'https://dzen.ru/news/story/Teatr_Astana_Balet_predstavil_afishu_nayanvar--67fb3a097ea2b5c3c29ece3312360dfe?lang=ru&rubric=culture&fan=1&stid=suaYxAdO&t=1672592347&persistent_id=1191760380&story=0d916a0d-0ebf-58e3-beb4-50f2094bbc38&issue_tld=kz',
#   'new_date': '11:26'},
#  {'new_source': 'Экспресс К',
#   'new_text': 'Завораживающее видео с итогами 2022 года появилось в Сети',
#   'new_link': 'https://dzen.ru/news/story/Zavorazhivayushhee_video_sitogami_2022_goda_poyavilos_vSeti--86aa92a066297487c7514a0aaf32b888?lang=ru&rubric=culture&fan=1&t=1672592347&persistent_id=1238162040&story=6419ef06-ff05-5401-ad08-b321c1b85cbb&issue_tld=kz',
#   'new_date': '19:30'},
#  {'new_source': 'Телеканал 360°',
#   'new_text': '«360» составил небанальный список фильмов, которые стоит посмотреть на каникулах',
#   'new_link': 'https://dzen.ru/news/story/360_sostavil_nebanalnyj_spisok_filmov_kotorye_stoit_posmotret_nakanikulakh--adbbeeaedb92d43888e467fdd16f9b14?lang=ru&rubric=culture&fan=1&stid=-xrLRiSY&t=1672592347&persistent_id=1233360028&story=8a1c062b-4e54-543e-bd3a-c9e6736bafa1&issue_tld=kz',
#   'new_date': '20:49'},
#  {'new_source': 'Караван',
#   'new_text': 'От «нудных песен» до «не поставленного голоса»: как ругали и хвалили Димаша в 2022-м',
#   'new_link': 'https://dzen.ru/news/story/Otnudnykh_pesen_done_postavlennogo_golosa_kak_rugali_i_khvalili_Dimasha_v2022-m--0d9942952ff2e441af3a630cd4033e35?lang=ru&rubric=culture&fan=1&t=1672592347&persistent_id=1234564581&story=4e6bdb13-8965-5723-9059-21fc17b7491f&issue_tld=kz',
#   'new_date': '11:10'},
#  {'new_source': '24.kz',
#   'new_text': 'Выставка к 105-летию Айши Галимбаевой открылась в Павлодаре',
#   'new_link': 'https://dzen.ru/news/story/Vystavka_k105-letiyu_Ajshi_Galimbaevoj_otkrylas_vPavlodare--54c936eec29a3b77bf81c55a7fd874a7?lang=ru&rubric=culture&fan=1&t=1672592347&persistent_id=1234565232&story=57197dbc-2bc0-5ff0-ae48-75fa135d5543&issue_tld=kz',
#   'new_date': '12:02'},
#  {'new_source': 'LandofGames.ru',
#   'new_text': 'На Nintendo Switch могут выйти первые части серии Gothic',
#   'new_link': 'https://dzen.ru/news/story/NaNintendo_Switch_mogut_vyjti_pervye_chasti_serii_Gothic--b6fa665cc6b1994d0351544acc163fff?lang=ru&rubric=computers&fan=1&stid=N9r5S7ZMJW3aGZk2DszD&t=1672592347&persistent_id=1226960673&story=3027b786-8317-5d4a-ac8d-3e005fbd2dc6&issue_tld=kz',
#   'new_date': '20:53'},
#  {'new_source': 'Газета.Ru',
#   'new_text': 'OnePlus готовит к выпуску чарджер на 100 Вт для одновременной зарядки двух устройств',
#   'new_link': 'https://dzen.ru/news/story/OnePlus_gotovit_kvypusku_chardzher_na100Vt_dlyaodnovremennoj_zaryadki_dvukh_ustrojstv--4214181d50ebf285b784e14167aa2100?lang=ru&rubric=computers&fan=1&stid=37Irj0FpgRGKrMI6mvxU&t=1672592347&persistent_id=1226960368&story=0302a5d4-286a-58a9-81a8-96241fa9cc4c&issue_tld=kz',
#   'new_date': '20:14'},
#  {'new_source': 'PlayGround.ru',
#   'new_text': 'Продажи красочной ролевой игры OMORI превысили отметку в 1 миллион копий по всему миру',
#   'new_link': 'https://dzen.ru/news/story/Prodazhi_krasochnoj_rolevoj_igry_OMORI_prevysili_otmetku_v1_million_kopij_povsemu_miru--4ff2f7efa0ca37d2ab5a75b93f6b4971?lang=ru&rubric=computers&fan=1&stid=atRz&t=1672592347&persistent_id=1239360130&story=1a58389a-4306-587d-bf8d-c03aed9819a2&issue_tld=kz',
#   'new_date': '22:49'},
#  {'new_source': 'Ferra',
#   'new_text': 'Apple закрыла погодное приложение',
#   'new_link': 'https://dzen.ru/news/story/Apple_zakryla_pogodnoe_prilozhenie--aa3cdd54ff78de19b542ec1934faabc1?lang=ru&rubric=computers&fan=1&stid=HFbl&t=1672592347&persistent_id=1236560913&story=1d6a23a3-b3d9-5f82-958c-77b51600d4df&issue_tld=kz',
#   'new_date': '15:41'},
#  {'new_source': 'Superplanshet.ru',
#   'new_text': 'Hisense выпустила смартфон Hi Reader Pro с E-Ink дисплеем',
#   'new_link': 'https://dzen.ru/news/story/Hisense_vypustila_smartfon_Hi_Reader_Pro_sE-Ink_displeem--82829d6ee3fca95716d1d283c112aa18?lang=ru&rubric=computers&fan=1&stid=en1P&t=1672592347&persistent_id=1235760259&story=deb2ef29-5b6b-5db1-aed0-38b972d7bd79&issue_tld=kz',
#   'new_date': '21:36'},
#  {'new_source': '24.kz',
#   'new_text': 'Решение проблем Каспия требует объединения усилий',
#   'new_link': 'https://dzen.ru/news/story/Reshenie_problem_Kaspiya_trebuet_obedineniya_usilij--f022510413e6938f91723db5378aa950?lang=ru&rubric=science&fan=1&t=1672592347&persistent_id=1237360803&story=705a8cef-e6b3-543a-8936-65a9450745e9&issue_tld=kz',
#   'new_date': '17:03'},
#  {'new_source': 'Казинформ',
#   'new_text': 'Голограмму робота-домбриста создали школьники из Сарани',
#   'new_link': 'https://dzen.ru/news/story/Gologrammu_robota-dombrista_sozdali_shkolniki_izSarani--e64c1fd69ab110bc3af3d2c0b41d3e17?lang=ru&rubric=science&fan=1&t=1672592347&persistent_id=1232960758&story=4d6bf20f-7ec5-5c8e-838f-5e3409549d44&issue_tld=kz',
#   'new_date': 'вчера в 01:56'},
#  {'new_source': 'Юность Сибири',
#   'new_text': 'Учеными США выявлен участок мозга, ответственный за тягу к вредной пище и переедание',
#   'new_link': 'https://dzen.ru/news/story/Uchenymi_SSHA_vyyavlen_uchastok_mozga_otvetstvennyj_zatyagu_kvrednoj_pishhe_i_pereedanie--e28a2699b0e41695bc708ff1d29da523?lang=ru&rubric=science&fan=1&stid=uGn_BbzgeCM0B8YS&t=1672592347&persistent_id=1237760298&story=f90b293f-8243-52ec-84dc-cfe78a0e050d&issue_tld=kz',
#   'new_date': '22:18'},
#  {'new_source': 'INVOLTA TECHNOLOGIES',
#   'new_text': 'Ученые обнаружили основу «шестого чувства» человека',
#   'new_link': 'https://dzen.ru/news/story/Uchenye_obnaruzhili_osnovu_shestogo_chuvstva_cheloveka--2d497c210aa891fd3d4fce72eda4d24a?lang=ru&rubric=science&fan=1&stid=fHzBejITPxYT&t=1672592347&persistent_id=1230161274&story=ab7180c3-34f8-56bc-8b17-f0163f3f2ede&issue_tld=kz',
#   'new_date': '20:06'},
#  {'new_source': 'Юность Сибири',
#   'new_text': 'Канадский ученый Маркус Мюллер-Трапет выяснил, какой шум приводит к сердечным заболеваниям',
#   'new_link': 'https://dzen.ru/news/story/Kanadskij_uchenyj_Markus_Myuller-Trapet_vyyasnil_kakoj_shum_privodit_kserdechnym_zabolevaniyam--8c2d10c70190b208623862c890319942?lang=ru&rubric=science&fan=1&stid=m0JYZOo4&t=1672592347&persistent_id=1233360098&story=7133c7aa-5c43-524e-9470-5360d1adfde3&issue_tld=kz',
#   'new_date': '19:22'},
#  {'new_source': 'Автостат',
#   'new_text': 'В России стартуют продажи кроссовера Chery Tiggo 7 PRO Max',
#   'new_link': 'https://dzen.ru/news/story/VRossii_startuyut_prodazhi_krossovera_Chery_Tiggo_7_PRO_Max--6952a396f03d791c5bde07c47cb4d95e?lang=ru&rubric=auto&fan=1&stid=3fs5vrMX5WMqKvR1Vl_6&t=1672592347&persistent_id=1189761131&story=60a5efe8-8cc2-5ee0-ac4d-051ea7666804&issue_tld=kz',
#   'new_date': '22:00'},
#  {'new_source': 'Автоновости дня',
#   'new_text': 'Хайцеэр: неправильное использование мойки высокого давления может испортить краску машины',
#   'new_link': 'https://dzen.ru/news/story/KHajceehr_nepravilnoe_ispolzovanie_mojki_vysokogo_davleniya_mozhet_isportit_krasku_mashiny--88cad3b2f067f8312aa154b7d9336566?lang=ru&rubric=auto&fan=1&stid=aMwqX2pjj0VUJQJCiiYZ&t=1672592347&persistent_id=1238161205&story=c6458b84-4c09-551b-820c-8ff077d1ef5d&issue_tld=kz',
#   'new_date': '21:25'},
#  {'new_source': 'Автоновости дня',
#   'new_text': 'В России вступают в силу 5 изменений для водителей с 1 января 2023 года',
#   'new_link': 'https://dzen.ru/news/story/VRossii_vstupayut_vsilu_5_izmenenij_dlyavoditelej_s1_yanvarya_2023_goda--855ed9caec63964f0c3cdd64b2578e0e?lang=ru&rubric=auto&fan=1&stid=ihhsND16pezjsAtXDro1&t=1672592347&persistent_id=1185360483&story=7307e7b2-9549-5990-aa6b-9d6d0126a2f4&issue_tld=kz',
#   'new_date': '21:40'},
#  {'new_source': 'Tver-portal.ru',
#   'new_text': '«Коммерсантъ» рассказал, что будет с ценами на автомобили в 2023 году',
#   'new_link': 'https://dzen.ru/news/story/Kommersant_rasskazal_chto_budet_scenami_naavtomobili_v2023_godu--c3a4d9d09c2af131d9ccffdd1f047872?lang=ru&rubric=auto&fan=1&stid=BrL8AWLT&t=1672592347&persistent_id=1238161312&story=17515b50-e1f3-59da-bafa-28a4487c4f69&issue_tld=kz',
#   'new_date': '21:50'},
#  {'new_source': 'Автоновости дня',
#   'new_text': 'Таксопарки и сервисы каршеринга в России продолжат закупать автомашины из КНР в 2023 году',
#   'new_link': 'https://dzen.ru/news/story/Taksoparki_i_servisy_karsheringa_vRossii_prodolzhat_zakupat_avtomashiny_izKNR_v2023_godu--8fae69ba415bbcb05511fc24017e7ec9?lang=ru&rubric=auto&fan=1&stid=9-TrCqaHizRUGNuo4cEw&t=1672592347&persistent_id=1236560745&story=89d3f682-e2d0-5d71-8882-3393967d28aa&issue_tld=kz',
#   'new_date': '18:49'}]
